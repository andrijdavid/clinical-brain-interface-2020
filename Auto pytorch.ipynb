# %%
import pickle

# %%
x, y = pickle.load(open("data/train.pkl", "rb"))

# %%
test_name, x_test = pickle.load(open("data/test.pkl", "rb"))

# %%
from autoPyTorch import AutoNetClassification
from sklearn.model_selection import train_test_split
# data and metric imports
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)
# running Auto-PyTorch
autoPyTorch = AutoNetClassification("tiny_cs",  # config preset
                                    log_level='info',
                                    max_runtime=300,
                                    min_budget=30,
                                    max_budget=90)

autoPyTorch.fit(x_train, y_train, validation_split=0.3)
y_pred = autoPyTorch.predict(X_test)

print("Accuracy score", sklearn.metrics.accuracy_score(y_test, y_pred))
# Out:
# 17:10:28 [AutoNet] Start bohb
# 17:10:28 WORKER: start listening for jobs
# 17:10:28 DISPATCHER: started the 'discover_worker' thread
# 17:10:28 DISPATCHER: started the 'job_runner' thread
# 17:10:28 DISPATCHER: Pyro daemon running on 147.232.24.15:43513
# 17:10:28 DISPATCHER: discovered new worker, hpbandster.run_0.worker.redmine.cit.fei.tuke.sk.18950.-1140143504385856
# 17:10:28 HBMASTER: adjusted queue size to (0, 1)
# 17:10:28 DISPATCHER: A new worker triggered discover_worker
# 17:10:28 HBMASTER: starting run at 1585152628.829539
# 17:10:28 WORKER: start processing job (0, 0, 0)
# 17:10:28 Fit optimization pipeline
# 17:10:29 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:29 [AutoNet] CV split 0 of 1
# 17:10:29 Reduced initial budget 29.77475595474243 to cv budget 29.759175300598145 compensate for 0.01558065414428711
# 17:10:31 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:32 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 1, 'NetworkSelector:shapedresnet:max_units': 471, 'NetworkSelector:shapedresnet:num_groups': 3, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.001983593489385007, 'OptimizerSelector:sgd:momentum': 0.7759270051020887, 'OptimizerSelector:sgd:weight_decay': 0.023192474642911614, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:32 WORKER: registered result for job (0, 0, 0) with dispatcher
# 17:10:32 job (0, 0, 0) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.1709232330322266 seconds with budget 30.0
#
# 17:10:32 WORKER: start processing job (0, 0, 1)
# 17:10:32 Fit optimization pipeline
# 17:10:32 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:32 [AutoNet] CV split 0 of 1
# 17:10:32 Reduced initial budget 29.800535678863525 to cv budget 29.788318634033203 compensate for 0.012217044830322266
# 17:10:34 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:35 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 4, 'NetworkSelector:shapedresnet:max_units': 70, 'NetworkSelector:shapedresnet:num_groups': 9, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.00018615796258149428, 'OptimizerSelector:sgd:momentum': 0.39817961260426027, 'OptimizerSelector:sgd:weight_decay': 0.05953067205444034, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:35 WORKER: registered result for job (0, 0, 1) with dispatcher
# 17:10:35 job (0, 0, 1) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.1328847408294678 seconds with budget 30.0
#
# 17:10:35 WORKER: start processing job (0, 0, 2)
# 17:10:35 Fit optimization pipeline
# 17:10:35 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:35 [AutoNet] CV split 0 of 1
# 17:10:35 Reduced initial budget 29.79386305809021 to cv budget 29.780811548233032 compensate for 0.013051509857177734
# 17:10:38 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:38 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 4, 'NetworkSelector:shapedresnet:max_units': 18, 'NetworkSelector:shapedresnet:num_groups': 1, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.0011799619755919009, 'OptimizerSelector:sgd:momentum': 0.18353323291147042, 'OptimizerSelector:sgd:weight_decay': 0.036766590477157496, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:38 WORKER: registered result for job (0, 0, 2) with dispatcher
# 17:10:38 job (0, 0, 2) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.0828425884246826 seconds with budget 30.0
# 17:10:38 WORKER: start processing job (0, 1, 0)
# 17:10:38 Fit optimization pipeline
# 17:10:38 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:38 [AutoNet] CV split 0 of 1
# 17:10:38 Reduced initial budget 89.80597186088562 to cv budget 89.78976535797119 compensate for 0.01620650291442871
# 17:10:41 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:41 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 1, 'NetworkSelector:shapedresnet:max_units': 97, 'NetworkSelector:shapedresnet:num_groups': 8, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.00046024080572872023, 'OptimizerSelector:sgd:momentum': 0.332819549454932, 'OptimizerSelector:sgd:weight_decay': 0.08927689508684436, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:41 WORKER: registered result for job (0, 1, 0) with dispatcher
# 17:10:41 job (0, 1, 0) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.1200129985809326 seconds with budget 90.0
#
# 17:10:41 WORKER: start processing job (1, 0, 0)
# 17:10:41 Fit optimization pipeline
# 17:10:41 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:41 [AutoNet] CV split 0 of 1
# 17:10:41 Reduced initial budget 89.80390667915344 to cv budget 89.78811931610107 compensate for 0.015787363052368164
# 17:10:44 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:44 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 4, 'NetworkSelector:shapedresnet:max_units': 539, 'NetworkSelector:shapedresnet:num_groups': 2, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.000715855243549806, 'OptimizerSelector:sgd:momentum': 0.29886014336497374, 'OptimizerSelector:sgd:weight_decay': 0.09218696209529562, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:44 WORKER: registered result for job (1, 0, 0) with dispatcher
# 17:10:44 job (1, 0, 0) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.072580337524414 seconds with budget 90.0
#
# 17:10:44 WORKER: start processing job (1, 0, 1)
# 17:10:44 Fit optimization pipeline
# 17:10:44 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:44 [AutoNet] CV split 0 of 1
# 17:10:44 Reduced initial budget 89.81481719017029 to cv budget 89.80201435089111 compensate for 0.012802839279174805
# 17:10:47 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:47 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 2, 'NetworkSelector:shapedresnet:max_units': 47, 'NetworkSelector:shapedresnet:num_groups': 6, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.0639593605691238, 'OptimizerSelector:sgd:momentum': 0.47493645091089376, 'OptimizerSelector:sgd:weight_decay': 0.02807972252624368, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:47 WORKER: registered result for job (1, 0, 1) with dispatcher
# 17:10:47 job (1, 0, 1) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.0989811420440674 seconds with budget 90.0
#
# 17:10:47 WORKER: start processing job (2, 0, 0)
# 17:10:47 Fit optimization pipeline
# 17:10:47 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:47 [AutoNet] CV split 0 of 1
# 17:10:47 Reduced initial budget 29.79204487800598 to cv budget 29.776093006134033 compensate for 0.015951871871948242
# 17:10:50 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:50 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 1, 'NetworkSelector:shapedresnet:max_units': 52, 'NetworkSelector:shapedresnet:num_groups': 2, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.0002699972153960292, 'OptimizerSelector:sgd:momentum': 0.32477033724199544, 'OptimizerSelector:sgd:weight_decay': 0.025306710812992527, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:50 WORKER: registered result for job (2, 0, 0) with dispatcher
# 17:10:50 job (2, 0, 0) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.1221344470977783 seconds with budget 30.0
#
# 17:10:50 WORKER: start processing job (2, 0, 1)
# 17:10:50 Fit optimization pipeline
# 17:10:51 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:51 [AutoNet] CV split 0 of 1
# 17:10:51 Reduced initial budget 29.7847580909729 to cv budget 29.77245283126831 compensate for 0.012305259704589844
# 17:10:53 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:53 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 3, 'NetworkSelector:shapedresnet:max_units': 24, 'NetworkSelector:shapedresnet:num_groups': 2, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.038924208445318326, 'OptimizerSelector:sgd:momentum': 0.5049305065391081, 'OptimizerSelector:sgd:weight_decay': 0.05917052138764401, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:10:53 WORKER: registered result for job (2, 0, 1) with dispatcher
# 17:10:53 job (2, 0, 1) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.106602430343628 seconds with budget 30.0
#
# 17:10:53 WORKER: start processing job (2, 0, 2)
# 17:10:53 Fit optimization pipeline
# 17:10:54 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:10:54 [AutoNet] CV split 0 of 1
# 17:10:54 Reduced initial budget 29.803632736206055 to cv budget 29.79044485092163 compensate for 0.013187885284423828
# 17:10:56 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:10:57 Exception occurred using config:
# ...
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:13:51 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 3, 'NetworkSelector:shapedresnet:max_units': 484, 'NetworkSelector:shapedresnet:num_groups': 6, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.0017352927360739672, 'OptimizerSelector:sgd:momentum': 0.23039790785635525, 'OptimizerSelector:sgd:weight_decay': 0.004796649540888819, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:13:51 WORKER: registered result for job (20, 1, 0) with dispatcher
# 17:13:51 job (20, 1, 0) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.6452441215515137 seconds with budget 90.0
#
# 17:13:51 WORKER: start processing job (21, 0, 0)
# 17:13:51 Fit optimization pipeline
# 17:13:51 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:13:51 [AutoNet] CV split 0 of 1
# 17:13:51 Reduced initial budget 89.91397857666016 to cv budget 89.91344094276428 compensate for 0.0005376338958740234
# 17:13:55 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:13:55 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 1, 'NetworkSelector:shapedresnet:max_units': 61, 'NetworkSelector:shapedresnet:num_groups': 3, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.0007548608039115095, 'OptimizerSelector:sgd:momentum': 0.44476709507160916, 'OptimizerSelector:sgd:weight_decay': 0.02126858987712505, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:13:55 WORKER: registered result for job (21, 0, 0) with dispatcher
# 17:13:55 job (21, 0, 0) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.6880056858062744 seconds with budget 90.0
#
# 17:13:55 WORKER: start processing job (21, 0, 1)
# 17:13:55 Fit optimization pipeline
# 17:13:55 [AutoNet] No validation set given and either no cross validator given or budget too low for CV. Continue by splitting 0.3 of training data.
# 17:13:55 [AutoNet] CV split 0 of 1
# 17:13:55 Reduced initial budget 89.9024863243103 to cv budget 89.90194988250732 compensate for 0.0005364418029785156
# 17:13:59 The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/pynisher-0.5.0-py3.7.egg/pynisher/limit_function_call.py", line 93, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 124, in optimize_pipeline
#     raise e
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 118, in optimize_pipeline
#     refit=False, rescore=False, hyperparameter_config_id=config_id, dataset_info=self.dataset_info)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/cross_validation.py", line 108, in fit
#     result = self.sub_pipeline.fit_pipeline(X=X, Y=Y, **sub_pipeline_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/pipeline.py", line 60, in fit_pipeline
#     return self.root.fit_traverse(**kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/base/node.py", line 115, in fit_traverse
#     node.fit_output = node.fit(**required_kwargs)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in fit
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/imputation.py", line 29, in <listcomp>
#     dataset_info.categorical_features = [dataset_info.categorical_features[i] for i, is_nan in enumerate(all_nan) if not is_nan]
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# 17:13:59 Exception occurred using config:
# {'CreateDataLoader:batch_size': 125, 'Imputation:strategy': 'median', 'InitializationSelector:initialization_method': 'default', 'InitializationSelector:initializer:initialize_bias': 'No', 'LearningrateSchedulerSelector:lr_scheduler': 'cosine_annealing', 'LossModuleSelector:loss_module': 'cross_entropy_weighted', 'NetworkSelector:network': 'shapedresnet', 'NormalizationStrategySelector:normalization_strategy': 'standardize', 'OptimizerSelector:optimizer': 'sgd', 'PreprocessorSelector:preprocessor': 'truncated_svd', 'ResamplingStrategySelector:over_sampling_method': 'none', 'ResamplingStrategySelector:target_size_strategy': 'none', 'ResamplingStrategySelector:under_sampling_method': 'none', 'TrainNode:batch_loss_computation_technique': 'standard', 'LearningrateSchedulerSelector:cosine_annealing:T_max': 10, 'LearningrateSchedulerSelector:cosine_annealing:T_mult': 2, 'NetworkSelector:shapedresnet:activation': 'relu', 'NetworkSelector:shapedresnet:blocks_per_group': 2, 'NetworkSelector:shapedresnet:max_units': 15, 'NetworkSelector:shapedresnet:num_groups': 4, 'NetworkSelector:shapedresnet:resnet_shape': 'brick', 'NetworkSelector:shapedresnet:use_dropout': 0, 'NetworkSelector:shapedresnet:use_shake_drop': 0, 'NetworkSelector:shapedresnet:use_shake_shake': 0, 'OptimizerSelector:sgd:learning_rate': 0.0029242011506694105, 'OptimizerSelector:sgd:momentum': 0.4334419831450785, 'OptimizerSelector:sgd:weight_decay': 0.014255218256197268, 'PreprocessorSelector:truncated_svd:target_dim': 100}
# 17:13:59 WORKER: registered result for job (21, 0, 1) with dispatcher
# 17:13:59 job (21, 0, 1) failed with exception
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/worker.py", line 206, in start_computation
#     result = {'result': self.compute(*args, config_id=id, **kwargs),
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/worker.py", line 86, in compute
#     raise Exception("Exception in train pipeline. Took " + str((time.time()-start_time)) + " seconds with budget " + str(budget))
# Exception: Exception in train pipeline. Took 3.7003862857818604 seconds with budget 90.0
#
# 17:13:59 HBMASTER: Timelimit reached: wait for remaining 0 jobs
# 17:13:59 DISPATCHER: Dispatcher shutting down
# 17:13:59 DISPATCHER: shut down complete
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/optimization_algorithm.py", line 308, in parse_results
#     incumbent_trajectory = res.get_incumbent_trajectory(bigger_is_better=False, non_decreasing_budget=False)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/hpbandster-0.7.4-py3.7.egg/hpbandster/core/result.py", line 310, in get_incumbent_trajectory
#     return_dict['config_ids'].append(return_dict['config_ids'][-1])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/optimization_algorithm.py", line 131, in fit
#     res = self.parse_results(pipeline_config)
#   File "/opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/pipeline/nodes/optimization_algorithm.py", line 310, in parse_results
#     raise RuntimeError("Error parsing results. Check results.json and output for more details. An empty results.json is usually caused by a misconfiguration of AutoNet.")
# RuntimeError: Error parsing results. Check results.json and output for more details. An empty results.json is usually caused by a misconfiguration of AutoNet.
# Error parsing results. Check results.json and output for more details. An empty results.json is usually caused by a misconfiguration of AutoNet.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-80a346d9bd90> in <module>()
#      13                                     max_budget=90)
#      14
# ---> 15 autoPyTorch.fit(x_train, y_train, validation_split=0.3)
#      16 y_pred = autoPyTorch.predict(X_test)
#      17
#
# /opt/anaconda/envs/pytorch/lib/python3.7/site-packages/autoPyTorch-0.0.2-py3.7.egg/autoPyTorch/core/api.py in fit(self, X_train, Y_train, X_valid, Y_valid, refit, **autonet_config)
#     150
#     151         if "optimized_hyperparameter_config" not in self.fit_result.keys() or not self.fit_result["optimized_hyperparameter_config"]: # MODIFY
# --> 152             raise RuntimeError("No models fit during training, please retry with a larger max_runtime.")
#     153
#     154         if (refit):
#
# RuntimeError: No models fit during training, please retry with a larger max_runtime.
